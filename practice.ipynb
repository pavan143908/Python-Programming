# %%
n1=int(input('enter first number:'))
n2=int(input('enter another number:'))
if n1>n2:
  print(n1+n2)
  print(n1-n2)
  print(n1*n2)
  print(n1%n2)
# Out:
# 37
# 13
# 300
# 1

# %%
#wap to print even
n=int(input())
if n%2==0:
  print('even')

# %%
num=int(input('enter a num:'))
if num%3==0 and num%6==0:
  print(complex(num))
# Out:
# (18+0j)

# %%
import keyword
a=input()
if a in keyword.kwlist:
  print('it is a keyword')
# Out:
# it is a keyword

# %%
num=int(input())
if num%3==0:
  print("fizz")
# Out:
# fizz

# %%
num=int(input())
if num%2==0 and num%6==0:
  print(complex(num))
# Out:
# (6+0j)

# %%
n=int(input())
if n%3==0 and n%5==0:
  print(list(str(n)),type(n))
# Out:
# ['1', '3', '5'] <class 'int'>

# %%
n=int(input())
if n%2!=0:
  print(list(str(n)))
# Out:
# ['5', '0', '1']

# %%
n=int(input())
if (n//2)*2==n:
  print(tuple(str(n)))
# Out:
# ('2',)

# %%
n=4
if n%2==0:
  print(n**4)
# Out:
# 256
